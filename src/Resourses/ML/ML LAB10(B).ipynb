# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/TANISHKA DODIYA/Desktop/SEMESTER 7/ML/toy_dataset.csv')
df
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
plt.scatter(df['Age'], df['Income'])

# %%
km = KMeans(n_clusters = 25)
km
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=25, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
y_predicted = km.fit_predict(df[['Age', 'Income']])
y_predicted
# Out:
# array([14, 14,  8, ..., 21, 21,  6])

# %%
df['cluster']=y_predicted
df
# Out:
#         Number    City  Gender  Age    Income Illness  cluster
# 0            1  Dallas    Male   41   40367.0      No       14
# 1            2  Dallas    Male   54   45084.0      No       14
# 2            3  Dallas    Male   42   52483.0      No        8
# 3            4  Dallas    Male   40   40941.0      No       14
# 4            5  Dallas    Male   46   50289.0      No        8
# ...        ...     ...     ...  ...       ...     ...      ...
# 149995  149996  Austin    Male   48   93669.0      No       11
# 149996  149997  Austin    Male   25   96748.0      No        1
# 149997  149998  Austin    Male   26  111885.0      No       21
# 149998  149999  Austin    Male   25  111878.0      No       21
# 149999  150000  Austin  Female   37   87251.0      No        6
#
# [150000 rows x 7 columns]

# %%
df1=df[df.cluster==0]
df2=df[df.cluster==1]
df3=df[df.cluster==2]
df4=df[df.cluster==3]
df5=df[df.cluster==4]
df6=df[df.cluster==5]
df7=df[df.cluster==6]
df8=df[df.cluster==7]
df9=df[df.cluster==8]
df10=df[df.cluster==9]
df11=df[df.cluster==10]
df12=df[df.cluster==11]
df13=df[df.cluster==12]
df14=df[df.cluster==13]
df15=df[df.cluster==14]
df16=df[df.cluster==15]
df17=df[df.cluster==16]
df18=df[df.cluster==17]
df19=df[df.cluster==18]
df20=df[df.cluster==19]
df21=df[df.cluster==20]
df22=df[df.cluster==21]
df23=df[df.cluster==22]
df24=df[df.cluster==23]
df25=df[df.cluster==24]
df26=df[df.cluster==25]


plt.scatter(df1.Age,df1['Income'],color='black')
plt.scatter(df2.Age,df2['Income'],color='brown')
plt.scatter(df3.Age,df3['Income'],color='red')
plt.scatter(df4.Age,df4['Income'],color='orangered')
plt.scatter(df5.Age,df5['Income'],color='saddlebrown')
plt.scatter(df6.Age,df6['Income'],color='darkorange')
plt.scatter(df7.Age,df7['Income'],color='orange')
plt.scatter(df8.Age,df8['Income'],color='gold')
plt.scatter(df9.Age,df9['Income'],color='darkkhakhi')
plt.scatter(df10.Age,df10['Income'],color='olive')
plt.scatter(df11.Age,df11['Income'],color='yellowgreen')
plt.scatter(df12.Age,df12['Income'],color='lawngreen')
plt.scatter(df13.Age,df13['Income'],color='lightgreen')
plt.scatter(df14.Age,df14['Income'],color='darkgreen')
plt.scatter(df15.Age,df15['Income'],color='lime')
plt.scatter(df16.Age,df16['Income'],color='springgreen')
plt.scatter(df17.Age,df17['Income'],color='turquoise')
plt.scatter(df18.Age,df18['Income'],color='darkslategray')
plt.scatter(df19.Age,df19['Income'],color='aqua')
plt.scatter(df20.Age,df20['Income'],color='deepskyblue')
plt.scatter(df21.Age,df21['Income'],color='steelblue')
plt.scatter(df22.Age,df22['Income'],color='darkblue')
plt.scatter(df23.Age,df23['Income'],color='indigo')
plt.scatter(df24.Age,df24['Income'],color='purple')
plt.scatter(df25.Age,df25['Income'],color='magenta')
plt.scatter(df26.Age,df26['Income'],color='crimson')

plt.xlabel('Age')
plt.ylabel('Income')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\tanishka dodiya\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4288             try:
# -> 4289                 mcolors.to_rgba_array(kwcolor)
#    4290             except ValueError as err:
#
# c:\users\tanishka dodiya\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     366     if isinstance(c, str):
# --> 367         raise ValueError("Using a string of single character colors as "
#     368                          "a color sequence is not supported. The colors can "
#
# ValueError: Using a string of single character colors as a color sequence is not supported. The colors can be passed as an explicit list instead.
#
# ...
